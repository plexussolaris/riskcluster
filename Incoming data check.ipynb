# %%
import pandas as pd

# %%
df = pd.read_excel("all_merged_after_manual_llm_cleaned.xlsx")
df.head()
# Out:
#    Index Risk source  Initial severity  Initial likelihood  \
# 0      1     General                 4                   4
# 1      1     General                 4                   4
# 2      2     General                 4                   2
# 3      2     General                 4                   2
# 4      2     General                 4                   2
#
#    Initial risk score                            raw_measure_description  \
# 0                  16       SIMOPS meeting to be held prior to operation
# 1                  16                             LMRA to be carried out
# 2                   8  Oil spill kits and absorbent granules to be av...
# 3                   8             Drip trays to be used where applicable
# 4                   8          Pre-commissioning checks on all equipment
#
#    Confidence (%)  Residual severity  Residual likelihood  \
# 0              90                  4                    2
# ...

# %%
print(f"Nr. of consequence after first LLM pass: {df['Consequence'].unique().shape[0]}.")
# Out:
# Nr. of consequence after first LLM pass: 293.

# %%
print(f"Nr. of threats after first LLM pass: {df['Cause'].unique().shape[0]}.")
# Out:
# Nr. of threats after first LLM pass: 609.

# %%
merged_count = df[df['Cause'] != df['raw_cause_description']]['Index'].unique().shape[0]
print(f"Nr. of causes merged: {merged_count}")
# Out:
# Nr. of causes merged: 45
